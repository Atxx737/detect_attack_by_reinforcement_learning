# %% [markdown]
# # Can NOT be run all in once time

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # PATH src

# %%
DATASET_TRAINING_src = '/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/normal/train-normal.csv'

TEST_OK_csic2010='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/normal/test_csic2010-normal.csv'
TEST_OK_fwaf_queries='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/normal/test_fwaf-normal.csv'
TEST_OK_http_param='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/normal/test_http_param-normal.csv'

# %%
# create a sample data frame
df_train = pd.read_csv(DATASET_TRAINING_src)
df_test_csic = pd.read_csv(TEST_OK_csic2010)
df_test_fwaf = pd.read_csv(TEST_OK_fwaf_queries)
df_test_http = pd.read_csv(TEST_OK_http_param)

# %% [markdown]
# # Minmax Normalization

# %% [markdown]
# ## path Des minmax

# %%
TRAIN_PATH_minmax='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/minmax/train_minmax.csv'

TEST_csic2010_minmax='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/minmax/test_csic2010-minmax.csv'
TEST_fwaf_queries_minmax='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/minmax/test_fwaf-minmax.csv'
TEST_http_param_minmax='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/minmax/test_http_param-minmax.csv'

# %% [markdown]
# ### Train data

# %%
cols_to_keep = df_train.columns[:-1]
last_column = df_train.iloc[:, -1] 
# create a new dataframe with selected columns
df_new = df_train[cols_to_keep]
scaler = MinMaxScaler()
train_file = pd.DataFrame(scaler.fit_transform(df_new), columns=df_new.columns)

# %%
# print the last column
# print(last_column)

# # get the last column as a dataframe
# last_column_df = df_train.iloc[:, [-1]]

# # print the last column as a dataframe
# print(last_column_df)

# %%
# print the original and standardized data frames
# display(train_file)

# %%
train_file['Label'] = last_column
# display(train_file)

# %%
train_file.to_csv(TRAIN_PATH_minmax,index=False)

# %% [markdown]
# ### Test data

# %% [markdown]
# #### csic

# %%
cols_to_keep = df_test_csic.columns[:-1]
last_column = df_test_csic.iloc[:, -1] 
# create a new dataframe with selected columns
df_new_csic = df_test_csic[cols_to_keep]
scaler = MinMaxScaler()
test_file_csic = pd.DataFrame(scaler.fit_transform(df_new_csic), columns=df_new_csic.columns)

# %%
test_file_csic['Label'] = last_column
# display(train_file)

# %%
test_file_csic.to_csv(TEST_csic2010_minmax,index=False)

# %% [markdown]
# #### fwaf

# %%
cols_to_keep = df_test_fwaf.columns[:-1]
last_column = df_test_fwaf.iloc[:, -1] 
# create a new dataframe with selected columns
df_new_fwaf = df_test_fwaf[cols_to_keep]
scaler = MinMaxScaler()
test_file_fwaf = pd.DataFrame(scaler.fit_transform(df_new_fwaf), columns=df_new_fwaf.columns)

# %%
test_file_fwaf['Label'] = last_column
# display(train_file)

# %%
test_file_fwaf.to_csv(TEST_fwaf_queries_minmax,index=False)

# %% [markdown]
# #### http

# %%
cols_to_keep = df_test_http.columns[:-1]
last_column = df_test_http.iloc[:, -1] 
# create a new dataframe with selected columns
df_new_http = df_test_http[cols_to_keep]
scaler = MinMaxScaler()
test_file_http = pd.DataFrame(scaler.fit_transform(df_new_http), columns=df_new_http.columns)

# %%
test_file_http['Label'] = last_column
# display(train_file)

# %%
test_file_http.to_csv(TEST_http_param_minmax,index=False)
