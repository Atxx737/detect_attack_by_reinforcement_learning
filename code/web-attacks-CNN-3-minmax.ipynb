# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout, Conv1D, MaxPooling1D, GlobalAveragePooling1D, LSTM, Activation, GRU, SimpleRNN
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
import keras.callbacks as kcallbacks
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam



#20 normal + 20 anomalous = test / con lai la train
#fwap + http = train

# %% [markdown]
# # Path

# %% [markdown]
# ## Normal

# %%
# DATASET_TRAINING = '/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/normal/train-normal.csv'
# # DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/normal/test_csic2010-normal.csv'
# DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/normal/test_fwaf-normal.csv'
# # DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/normal/test_http_param-normal.csv'

# %% [markdown]
# ## minmax

# %%
DATASET_TRAINING = '/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/minmax/train_minmax.csv'
# DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/minmax/test_csic2010-minmax.csv'
# DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/minmax/test_fwaf-minmax.csv'
DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/minmax/test_http_param-minmax.csv'

# %% [markdown]
# ## binary

# %%
# DATASET_TRAINING = '/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/binary/train_binary.csv'
# DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/binary/test_csic2010-binary.csv'
# DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/binary/test_fwaf-binary.csv'
# DATASET_TESTING='/content/drive/MyDrive/UIT/HocKy8/KLTN/datasets/dataset1/matrix1/binary/test_http_param-binary.csv'

# %% [markdown]
# # load data

# %%
### Load data
df_train = pd.read_csv(DATASET_TRAINING)
# display(df_train)
# df_test = pd.read_csv(DATASET_TESTING, header=None, index_col=False)
df_test = pd.read_csv(DATASET_TESTING)

df_train = df_train.astype(float)
df_test = df_test.astype(float)

df_train = df_train.sample(frac = 1)
df_test = df_test.sample(frac = 1)

x_train, y_train = df_train.iloc[:, :-1], df_train.iloc[:, [-1]]
x_test, y_test = df_test.iloc[:, :-1], df_test.iloc[:, [-1]]

x_train = x_train/255.0
x_test = x_test/255.0

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1)

y_train = y_train.astype(int)
y_val = y_val.astype(int)
y_test = y_test.astype(int)

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

input_shape = x_train.shape[1]
output_shape = y_train.shape[1]

# %%
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
print(x_test.shape)
print(y_test.shape)
print(input_shape, output_shape)
# Out:
# (99954, 38)
# (99954, 2)
# (11107, 38)
# (11107, 2)
# (5660, 38)
# (5660, 2)
# 38 2

# %%
checkpoint_filepath = '/content/drive/MyDrive/UIT/HocKy8/KLTN/checkpoints/weights.{epoch:02d}-{val_loss:.2f}.h5'
model_checkpoint_callback = kcallbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %% [markdown]
# # CNN

# %% [markdown]
# ## CNN 1

# %%
# ### CNN 1
model = Sequential()
model.add(Conv1D(64, 3, padding="same",activation="relu",input_shape=(input_shape, 1)))
model.add(Conv1D(64, 3, padding="same", activation="relu"))
model.add(MaxPooling1D(pool_size=(2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(output_shape, activation="softmax"))

# define optimizer and objective, compile cnn

model.compile(loss="categorical_crossentropy", optimizer="adam",metrics=['accuracy'])

# train
early_stop = kcallbacks.EarlyStopping(monitor='val_accuracy', patience=2, verbose=1, mode='auto')
history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# # loss: 0.2412 - accuracy: 0.8811
# Out:
# Epoch 1/100
# 1562/1562 [==============================] - 30s 18ms/step - loss: 0.6846 - accuracy: 0.5667 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 2/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 3/100
# 1562/1562 [==============================] - 29s 19ms/step - loss: 0.6844 - accuracy: 0.5668 - val_loss: 0.6826 - val_accuracy: 0.5737
# Epoch 4/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 5/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 6/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6826 - val_accuracy: 0.5737
# Epoch 7/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 8/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6826 - val_accuracy: 0.5737
# Epoch 9/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 10/100
# 1562/1562 [==============================] - 29s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 11/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 12/100
# 1562/1562 [==============================] - 29s 19ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 13/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 14/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 15/100
# 1562/1562 [==============================] - 25s 16ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 16/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6825 - val_accuracy: 0.5737
# Epoch 17/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 18/100
# 1562/1562 [==============================] - 29s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 19/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 20/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 21/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6826 - val_accuracy: 0.5737
# Epoch 22/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 23/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 24/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6826 - val_accuracy: 0.5737
# Epoch 25/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 26/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 27/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6822 - val_accuracy: 0.5737
# Epoch 28/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 29/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 30/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 31/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 32/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 33/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 34/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 35/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6826 - val_accuracy: 0.5737
# Epoch 36/100
# 1562/1562 [==============================] - 29s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 37/100
# 1562/1562 [==============================] - 29s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 38/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 39/100
# 1562/1562 [==============================] - 26s 16ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 40/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6825 - val_accuracy: 0.5737
# Epoch 41/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6822 - val_accuracy: 0.5737
# Epoch 42/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 43/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6822 - val_accuracy: 0.5737
# Epoch 44/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6829 - val_accuracy: 0.5737
# Epoch 45/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 46/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 47/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 48/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6825 - val_accuracy: 0.5737
# Epoch 49/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 50/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 51/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6825 - val_accuracy: 0.5737
# Epoch 52/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 53/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6825 - val_accuracy: 0.5737
# Epoch 54/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 55/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 56/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6825 - val_accuracy: 0.5737
# Epoch 57/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 58/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 59/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 60/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 61/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 62/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6825 - val_accuracy: 0.5737
# Epoch 63/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 64/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 65/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6826 - val_accuracy: 0.5737
# Epoch 66/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 67/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 68/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 69/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 70/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 71/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 72/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 73/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 74/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 75/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 76/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 77/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 78/100
# 1562/1562 [==============================] - 27s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 79/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 80/100
# 1562/1562 [==============================] - 26s 16ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 81/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 82/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6826 - val_accuracy: 0.5737
# Epoch 83/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 84/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 85/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 86/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 87/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6828 - val_accuracy: 0.5737
# Epoch 88/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6824 - val_accuracy: 0.5737
# Epoch 89/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 90/100
# 1562/1562 [==============================] - 27s 17ms/step - loss: 0.6843 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 91/100
# 1562/1562 [==============================] - 26s 17ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 92/100
# 1562/1562 [==============================] - 28s 18ms/step - loss: 0.6842 - accuracy: 0.5668 - val_loss: 0.6823 - val_accuracy: 0.5737
# Epoch 93/100
#  427/1562 [=======>......................] - ETA: 21s - loss: 0.6841 - accuracy: 0.5674

# %% [markdown]
# ## CNN 2

# %%
# ### CNN 2
# model = Sequential()

# model.add(Conv1D(64, 3, activation="relu", padding='same', input_shape=(input_shape, 1)))
# model.add(MaxPooling1D(pool_size=(2)))

# model.add(Flatten())
# model.add(Dense(128, activation="relu"))
# model.add(Dropout(0.5))
# model.add(Dense(output_shape, activation="softmax"))

# # define optimizer and objective, compile cnn
# model.compile(loss="categorical_crossentropy", optimizer="adam",metrics=['accuracy'])

# early_stop = kcallbacks.EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
# #fit model
# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=20, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# # # loss: 0.2433 - accuracy: 0.8846 - 128
# # # loss: 0.2384 - accuracy: 0.8884 - 64
# # # loss: 0.2347 - accuracy: 0.8934 - 32

# %% [markdown]
# ## CNN 3

# %%
# ### CNN 3
# model = Sequential()
# model.add(Conv1D(64, 3, padding="same",activation="relu",input_shape=(input_shape, 1)))
# model.add(Conv1D(64, 3, padding="same", activation="relu"))
# model.add(MaxPooling1D(pool_size=(2)))
# model.add(Conv1D(128, 3, padding="same", activation="relu"))
# model.add(Conv1D(128, 3, padding="same", activation="relu"))
# model.add(MaxPooling1D(pool_size=(2)))
# model.add(Flatten())
# model.add(Dense(128, activation="relu"))
# model.add(Dropout(0.5))
# model.add(Dense(output_shape, activation="softmax"))

# # define optimizer and objective, compile cnn
# model.compile(loss="categorical_crossentropy", optimizer="adam",metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# # loss: 0.2384 - accuracy: 0.8908

# %% [markdown]
# ## CNN5

# %%
# ### CNN5
# model = Sequential()
# model.add(Conv1D(16, 3, padding="same",activation="relu",input_shape=(input_shape, 1)))
# model.add(Conv1D(64, 3, padding="same", activation="relu"))
# model.add(MaxPooling1D(pool_size=(2)))
# model.add(Conv1D(128, 3, padding="same", activation="relu"))
# model.add(MaxPooling1D(pool_size=(2)))
# model.add(Flatten())
# model.add(Dense(128, activation="relu"))
# model.add(Dropout(0.5))
# model.add(Dense(output_shape, activation="softmax"))

# # define optimizer and objective, compile cnn
# model.compile(loss="categorical_crossentropy", optimizer="adam",metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# %% [markdown]
# ## CNN6

# %%
# ### CNN6
# model = Sequential()
# model.add(Conv1D(16, 3, padding="same",activation="relu",input_shape=(input_shape, 1)))
# model.add(Conv1D(64, 3, padding="same", activation="relu"))
# model.add(MaxPooling1D(pool_size=(2)))
# model.add(Conv1D(128, 3, padding="same", activation="relu"))
# model.add(MaxPooling1D(pool_size=(2)))
# model.add(Conv1D(256, 3, padding="same", activation="relu"))
# model.add(MaxPooling1D(pool_size=(2)))
# model.add(Conv1D(256, 3, padding="same", activation="relu"))
# model.add(MaxPooling1D(pool_size=(2)))
# model.add(Flatten())
# model.add(Dense(256, activation="relu"))
# model.add(Dropout(0.5))
# model.add(Dense(output_shape, activation="softmax"))

# # define optimizer and objective, compile cnn
# model.compile(loss="categorical_crossentropy", optimizer="adam",metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# %% [markdown]
# ## CNN + LSTM

# %%
# ### LSTM
# model = Sequential()
# model.add(LSTM(2, input_shape=(input_shape, 1), return_sequences=True, activation='sigmoid'))
# model.add(LSTM(units=120, recurrent_activation='hard_sigmoid', activation='sigmoid'))
# model.add(Dense(activation='sigmoid', units=output_shape))
# adam=Adam(learning_rate=0.01)

# model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# early_stop = kcallbacks.EarlyStopping(monitor='val_accuracy', patience=2, verbose=1, mode='auto')
# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# # loss: 0.4802 - accuracy: 0.7314

# %% [markdown]
# # LSTM

# %% [markdown]
# ## LSTM 2

# %%
# ## LSTM 2
# model = Sequential()
# model.add(LSTM(4,input_shape=(input_shape, 1)))
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# # loss: 0.4497 - accuracy: 0.7483

# %% [markdown]
# ## LSTM 3

# %%
# ### LSTM 3
# model = Sequential()
# model.add(LSTM(8,input_dim=input_shape, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(LSTM(8,input_dim=input_shape, return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# %% [markdown]
# ## LSTM 4

# %%
# ### LSTM 4
# model = Sequential()
# model.add(LSTM(16,input_dim=input_shape, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(LSTM(16, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(LSTM(16, return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# %% [markdown]
# ## LSTM 5

# %%
# ### LSTM 5
# model = Sequential()
# model.add(LSTM(64,input_dim=input_shape, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(LSTM(64,return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(LSTM(64, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(LSTM(64, return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)

# %% [markdown]
# # GRU

# %% [markdown]
# ## GRU 1

# %%
# ### GRU 1
# model = Sequential()
# model.add(GRU(4,input_shape=(input_shape, 1)))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=32, callbacks=[model_checkpoint_callback], shuffle=True)

# # loss: 0.6380 - accuracy: 0.6299

# %% [markdown]
# ## GRU 2

# %%
# ### GRU 2
# model = Sequential()
# model.add(GRU(8,input_shape=(input_shape, 1), return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(GRU(8,input_shape=(input_shape, 1), return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=30, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)
# # loss: 0.4454 - accuracy: 0.7774

# %% [markdown]
# ## GRU 3

# %%
# ### GRU 3
# model = Sequential()
# model.add(GRU(16,input_shape=(input_shape, 1), return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(GRU(16, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(GRU(16, return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=30, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)
# # loss: 0.3558 - accuracy: 0.8156

# %% [markdown]
# ## GRU 4

# %%
# ### GRU 4
# model = Sequential()
# model.add(GRU(64,input_shape=(input_shape, 1), return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(GRU(64,return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(GRU(64, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(GRU(64, return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=30, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)
# # loss: 0.2769 - accuracy: 0.8616

# %% [markdown]
# # SimpleRNN

# %% [markdown]
# ## SimpleRNN 1

# %%
# ### SimpleRNN 1
# model = Sequential()
# model.add(SimpleRNN(4,input_shape=(input_shape, 1)))
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=32, callbacks=[model_checkpoint_callback], shuffle=True)

# # loss: 0.5145 - accuracy: 0.7150

# %% [markdown]
# ## SimpleRNN 2

# %%
# ### SimpleRNN 2
# model = Sequential()
# model.add(SimpleRNN(8,input_shape=(input_shape, 1), return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(SimpleRNN(8,input_shape=(input_shape, 1), return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=30, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)
# # loss: 0.4497 - accuracy: 0.7519

# %% [markdown]
# ## SimpleRNN 3

# %%
# ### SimpleRNN 3
# model = Sequential()
# model.add(SimpleRNN(16,input_shape=(input_shape, 1), return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(SimpleRNN(16, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(SimpleRNN(16, return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=30, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)
# #loss: 0.3500 - accuracy: 0.8229

# %% [markdown]
# ## Simple RNN 4

# %%
# ### Simple RNN 4
# model = Sequential()
# model.add(SimpleRNN(64,input_shape=(input_shape, 1), return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(SimpleRNN(64,return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(SimpleRNN(64, return_sequences=True))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(SimpleRNN(64, return_sequences=False))  # try using a GRU instead, for fun
# model.add(Dropout(0.1))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=30, batch_size=64, callbacks=[model_checkpoint_callback], shuffle=True)
# # loss: 0.6376 - accuracy: 0.6803

# %% [markdown]
# # DNN

# %%
# ### DNN
# model = Sequential()
# model.add(Dense(1024,input_dim=input_shape,activation='relu'))  
# model.add(Dropout(0.01))
# model.add(Dense(output_shape))
# model.add(Activation('softmax'))

# # try using different optimizers and different optimizer configs
# model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# history=model.fit(x_train, y_train, validation_data=(x_val,y_val), epochs=100, batch_size=32, callbacks=[model_checkpoint_callback], shuffle=True)

# # loss: 0.2518 - accuracy: 0.8580

# %% [markdown]
# # Evaluate on test data

# %%
print("Evaluate on test data")
results = model.evaluate(x_test, y_test, batch_size=32)
print("test loss, test acc:", results)

# %% [markdown]
# Evaluate on test data - csic2010 - CNN1
#
# loss: 0.6896 - accuracy: 0.5467
# test loss, test acc: [0.6895982623100281, 0.5466970205307007]
#
# Evaluate on test data - fwap - CNN1
#
# loss: 0.6922 - accuracy: 0.5374
# test loss, test acc: [0.6921736598014832, 0.5373728275299072]
#
# Evaluate on test data - http - CNN1
#
# 177/177 [==============================] - 0s 2ms/step - loss: 0.3740 - accuracy: 0.9260
#
# test loss, test acc: [0.3740072548389435, 0.9259717464447021]

# %% [markdown]
# # CNN2

# %% [markdown]
# Evaluate on test data - csic2010 - 100 epoch - CNN2
#
# loss: 1.3206 - accuracy: 0.6435
# test loss, test acc: [1.3205711841583252, 0.6435079574584961]
#
# Evaluate on test data - fwaf - 100 epoch - CNN2
#
# loss: 0.0259 - accuracy: 0.9944
# test loss, test acc: [0.02590016834437847, 0.994397759437561]
#
# Evaluate on test data - http - 100 epoch - CNN2
#
# loss: 0.3838 - accuracy: 0.9256
# test loss, test acc: [0.383787602186203, 0.9256183505058289]
