# %% [markdown]
# # Can run all in once time

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from random import shuffle
import pandas as pd
from sklearn.utils import shuffle

# %% [markdown]
# ## PATH dataset

# %%
TRAIN_PATH='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/normal/train-normal.csv'

# %%
GOOD_OK_csic2010_src='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/origin/OK_csic2010-normal.csv'
BAD_OK_csic2010_src='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/origin/OK_csic2010-anomalous.csv'
TEST_OK_csic2010='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/normal/test_csic2010-normal.csv'

# %%
GOOD_OK_fwaf_queries_src='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/origin/OK_fwaf-goodqueries.csv'
BAD_OK_fwaf_queries_src='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/origin/OK_fwaf-badqueries.csv'
TEST_OK_fwaf_queries='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/normal/test_fwaf-normal.csv'

# %%
GOOD_OK_http_param_src='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/origin/OK_http-params-normal.csv'
BAD_OK_http_param_src='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/origin/OK_http-params-anomalous.csv'
TEST_OK_http_param='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/normal/test_http_param-normal.csv'

# %% [markdown]
# # csic (1), fwaf (2), http param (3) mỗi bộ đều có normal(A) và anorm(B)
# ### train = 80%(A1 + B1 + A2 + B2 + A3 + B3)
# ### test1 = 20%(A1+B1)
# ### test2 = 20%(A2+B2)
# ### test3 = 20%(A3+B3)

# %% [markdown]
# # CREATE dataset

# %% [markdown]
# ### data from OK_csic2010

# %%
# get good data
df_good = pd.read_csv(GOOD_OK_csic2010_src)
good_to_test = df_good.sample(frac=0.2, random_state=1)
good_to_test.shape[0]
# Out:
# 960

# %%
# get bad data
df_bad = pd.read_csv(BAD_OK_csic2010_src)
bad_to_test = df_bad.sample(frac=0.2, random_state=1)
bad_to_test.shape[0]
# Out:
# 796

# %%
# create test from csic2010
TEST_csic2010 =  pd.concat([good_to_test,bad_to_test]) 
TEST_csic2010.shape[0]
TEST_csic2010.to_csv(TEST_OK_csic2010,index=False)

# %%
# get 80% data to train
good_to_train = df_good.drop(good_to_test.index)
bad_to_train = df_bad.drop(bad_to_test.index)
TRAIN_csic2010 = pd.concat([good_to_train,bad_to_train]) 
TRAIN_csic2010.shape[0]
# Out:
# 7027

# %% [markdown]
# ### data from OK_fwaf

# %%
# get good data
df_good = pd.read_csv(GOOD_OK_fwaf_queries_src)
good_to_test = df_good.sample(frac=0.2, random_state=1)
good_to_test.shape[0]
# Out:
# 10935

# %%
#get bad data
df_bad = pd.read_csv(BAD_OK_fwaf_queries_src)
bad_to_test = df_bad.sample(frac=0.2, random_state=1)
bad_to_test.shape[0]
# Out:
# 9414

# %%
# create test from fwaf
TEST_fwaf =  pd.concat([good_to_test,bad_to_test]) 
TEST_fwaf.shape[0]
TEST_fwaf.to_csv(TEST_OK_fwaf_queries,index=False)

# %%
# get 80% to train
good_to_train = df_good.drop(good_to_test.index)
bad_to_train = df_bad.drop(bad_to_test.index)
TRAIN_fwaf = pd.concat([good_to_train,bad_to_train])
TRAIN_fwaf.shape[0]
# Out:
# 81393

# %% [markdown]
# ### data from http-params

# %%
# get good data
df_good = pd.read_csv(GOOD_OK_http_param_src)
good_to_test = df_good.sample(frac=0.2, random_state=1)
good_to_test.shape[0]
# Out:
# 3860

# %%
#get bad data
df_bad = pd.read_csv(BAD_OK_http_param_src)
bad_to_test = df_bad.sample(frac=0.2, random_state=1)
bad_to_test.shape[0]
# Out:
# 1800

# %%
# create test from http
TEST_http =  pd.concat([good_to_test,bad_to_test]) 
TEST_http.shape[0]
TEST_http.to_csv(TEST_OK_http_param,index=False)

# %%
# get 80% to train
good_to_train = df_good.drop(good_to_test.index)
bad_to_train = df_bad.drop(bad_to_test.index)
TRAIN_http_param = pd.concat([good_to_train,bad_to_train])
TRAIN_http_param.shape[0]
# Out:
# 22641

# %% [markdown]
# ### train data

# %%
connect_data = pd.concat([TRAIN_csic2010,TRAIN_fwaf,TRAIN_http_param])

shuffle(connect_data).to_csv(TRAIN_PATH,index=False)

# %% [markdown]
# # Summary

# %%
# dataframe of train
df_train = pd.read_csv(TRAIN_PATH)
df_train.shape[0]
# Out:
# 111061

# %%
# dataframe of test http
df_TEST_http = pd.read_csv(TEST_OK_http_param)
df_TEST_http.shape[0]
# Out:
# 5660

# %%
# dataframe of test fwaf

df_TEST_fwaf = pd.read_csv(TEST_OK_fwaf_queries)
df_TEST_fwaf.shape[0]
# Out:
# 20349

# %%
# dataframe of test csic
df_TEST_csic = pd.read_csv(TEST_OK_csic2010)
df_TEST_csic.shape[0]
# Out:
# 1756
