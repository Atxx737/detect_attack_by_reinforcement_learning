# %% [markdown]
# # Can be run all in once time

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # PATH src

# %%
DATASET_TRAINING_src = '/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/normal/train-normal.csv'

TEST_OK_csic2010='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/normal/test_csic2010-normal.csv'
TEST_OK_fwaf_queries='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/normal/test_fwaf-normal.csv'
TEST_OK_http_param='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/normal/test_http_param-normal.csv'

# %%
# create a sample data frame
df_train = pd.read_csv(DATASET_TRAINING_src)
df_test_csic = pd.read_csv(TEST_OK_csic2010)
df_test_fwaf = pd.read_csv(TEST_OK_fwaf_queries)
df_test_http = pd.read_csv(TEST_OK_http_param)

# %% [markdown]
# ## path Des binary

# %%
TRAIN_PATH_binary='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/binary/train_binary.csv'

TEST_csic2010_binary='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/binary/test_csic2010-binary.csv'
TEST_fwaf_queries_binary='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/binary/test_fwaf-binary.csv'
TEST_http_param_binary='/content/drive/MyDrive/UIT/HocKy8/KLTN/detect_attack_by_reinforcement_learning/data/matrix1/binary/test_http_param-binary.csv'

# %% [markdown]
# # Binary Normalization

# %%
def binary_normalization(x):
    if x >= 1 : 
      return 1
    else:
      return 0

# %%
train_file = df_train.applymap(binary_normalization)
test_file_csic = df_test_csic.applymap(binary_normalization)
test_file_fwaf = df_test_fwaf.applymap(binary_normalization)
test_file_http = df_test_http.applymap(binary_normalization)
# display(test_file)
# display(train_file)

# %%
train_file.to_csv(TRAIN_PATH_binary,index=False) 
test_file_csic.to_csv(TEST_csic2010_binary,index=False) 
test_file_fwaf.to_csv(TEST_fwaf_queries_binary,index=False) 
test_file_http.to_csv(TEST_http_param_binary,index=False)
